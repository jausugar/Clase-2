# %%
import sys
print(f"Version de python utilizada: {sys.version.split()[0]}")

import pandas as pd
import numpy as np
print(f"Version de pandas utilizada: {pd.__version__ }")
print(f"Version de Numpy {np.__version__ }")
# Out:
# Version de python utilizada: 3.10.19
# Version de pandas utilizada: 2.3.3
# Version de Numpy 2.2.6

# %% [markdown]
# Python y Librerías

# %%
# conectar mi Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# Clase1.csv  drive  sample_data

# %%
import os
print("ubicacion actual:", os.getcwd())
# Out:
# ubicacion actual: /content

# %%
# ruta típica ''
ruta = '/content/drive/MyDrive/analisita-y-big-data'

# %%
#Instalar librerías (ejemplo para conectarse con MySQL)
# !pip install pymysql -q

# %%
import pymysql

# %%
# 1. creamos un archivo de texto simple
con_este_texto = "Hola, si descargaste esto, ya sabes usar Google Colab"

# %%
# descargR LA CARPETA DONDE ESTAMOS TRABAJANDO

with open('hola.txt', 'w') as archivo:
  archivo.write(con_este_texto)

# %%
ruta = '/content/'
os.chdir(ruta)

# %%
with open('hola.txt', 'a') as archivo:
  archivo.write("La Segunda linea")

# %%
ciudades_principales = ["Medellin", "Cali", "Barranquilla", "Cartagena", "Bucaramanga"]
